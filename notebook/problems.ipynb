# %% [markdown]
# # Hypothesis testing problems

# %% [markdown]
# ## Exercise 1
#
# You are a nutritionist researching two different types of diets to see if there is a significant difference in weight loss after one month. You choose two random groups of people, one group follows the first diet and the other follows the second. At the end of the month, you record the weight loss (in kg) for each person:
#
# | Diet 1 | Diet 2 |
# |:-------|:-------|
# | 2.0 | 3.0 |
# | 2.5 | 3.2 |
# | 3.0 | 3.1 |
# | 2.8 | 2.9 |
# | 2.3 | 2.8 |
# | 2.7 | 3.0 |
# | 2.5 | 3.2 |
#
# With these data, it seeks to answer the following question: is there a significant difference in average weight loss between people who followed the first diet and those who followed the second diet?
#
# To draw conclusions, follow the points below:
#
# - State the hypothesis: null and alternative hypothesis.
# - Perform the test to test the hypothesis. You can use a Student's t-test.
# - Analyze the conclusions.

# %%
import scipy.stats as stats

# TODO
#datasets for diet1 and diet2 by weight loss amount in kg
diet1 = [2.0, 2.5, 3.0, 2.8, 2.3, 2.7, 2.5]
diet2 = [3.0, 3.2, 3.1, 2.9, 2.8, 3.0, 3.2]

#Null Hypothesis 
print("The Null Hypothesis states that there is no difference in average weight loss between diet1 and diet2")

#Alternative Hypoythesis
print("The Alternative Hypothesis states that there is a difference in average weight loss between diet1 and diet2")

#students t-test

ttest_tvalue, ttest_pvalue = stats.ttest_ind(diet1,diet2)

#Analyze Conclusion
print("*"*20)
print(f"The t value from the results of the ttest is {ttest_tvalue}")
print(f"The p value from the results of the ttest is {ttest_pvalue}")
print("*"*20)
print("Since the p value is less that 5%(or .05), we would reject the null hypothesis and conclude that there is a significant difference in weight loss in diet1 and diet2")
print("If the p value had been greater than 5%, thatn we would accept the null hypothesis, suggesting that there is no significant difference.")
# Out:
# The Null hypothesis states that there is no difference in average weight loss between diet1 and diet2
# The alternative hypothesis states that there is a difference in average weight loss between diet1 and diet2
# ********************
# The t value from the results of the ttest is -3.5383407969933938
# The p value from the results of the ttest is 0.004083270191713912
# ********************
# Since the p value is less that 5%(or .05), we would reject the null hypothesis and conclude that there is a significant difference in weight loss in diet1 and diet2
# If the p value had been greater than 5%, thatn we would accept the null hypothesis, suggesting that there is no significant difference.

# %% [markdown]
# ## ANOVA
#
# **ANOVA** (*Analysis of Variance*) is a statistical technique used to compare the measures of two or more groups. The idea behind ANOVA is to decompose the total variability in the data into two components: between-group variability and within-group variability:
#
# - **Between-group variability**: This variability refers to the differences between the group means. If this variability is considerably larger than the within-group variability, it could be an indication that at least one of the group means is different.
# - **Within-group variability**: This variability refers to the dispersion of the data within each group. If all groups have similar variability, then any noticeable difference in group means could be considered significant.
#
# Hypotheses in ANOVA typically are:
#
# - **Null hypothesis** ($H₀$): The means of all groups are equal.
# - **Alternative hypothesis** ($H₁$): At least one of the group means is different.
#
# If the ANOVA test result is significant (e.g., a p-value less than a threshold such as 0.05), this suggests that at least one group mean is different.

# %% [markdown]
# ### Exercise 2
#
# A farmer decides to test three different types of fertilizers to determine if one is superior in terms of corn production. The farmer plants corn on 15 identical plots and uses all three fertilizers (5 plots for each type). At the end of the season, he measures the corn yield (in kg) of each plot, with the following result:
#
# | Fertilizer 1 | Fertilizer 2 | Fertilizer 3 |
# |:-------------|:-------------|:-------------|
# | 20 | 22 | 24 |
# | 21 | 21 | 23 |
# | 20 | 23 | 22 |
# | 19 | 22 | 23 |
# | 20 | 21 | 24 |
#
# With this data, he seeks to answer the following question: is there a significant difference in average corn yield between the three types of fertilizers?
#
# To help you, follow the points below:
#
# - State the hypothesis: null and alternative hypothesis.
# - Perform the ANOVA test.
# - Analyze the conclusions.
# - If one fertilizer is better than another, how can we know it?

# %%
import scipy.stats as stats
import numpy as np

fertilizer_1 = [20, 21, 20, 19, 20]
fertilizer_2 = [22, 21, 23, 22, 21]
fertilizer_3 = [24, 23, 22, 23, 24]

#Null Hypothesis 
print("The Null Hypothesis states that there is no difference in average corn yield between Fertiziler 1, Fertilizer 2, and Fertilizer 3.")

#Alternative Hypoythesis
print("The Alternative Hypothesis states that there is a difference in average corn yield between Fertiziler 1, Fertiziler 2, and Fertilizer 3")


#Perform the ANOVA test
f_value_anova_results, p_value_anova_results = stats.f_oneway(fertilizer_1, fertilizer_2, fertilizer_3)
print("*"*20)
print(f"The f value of the anova test is {f_value_anova_results}")
print(f"The p value of the anova test is {p_value_anova_results}")
print("*"*20)

#Analyze the conclusion

print("Since the significance level is less than 5%, we reject the null hypothesis.")

#If one fertilizer is better than another, how can we know it? (which group has the highest mean)
print("*"*20)
mean_fert1 = np.mean(fertilizer_1)
mean_fert2 = np.mean(fertilizer_2)
mean_fert3 = np.mean(fertilizer_3)
#print(mean_fert1)
#print(mean_fert2)
#print(mean_fert3)

def max_mean_label(mean_fert1, mean_fert2, mean_fert3):
    max_mean = max(mean_fert1, mean_fert2, mean_fert3)
    label = None
    if max_mean == mean_fert1:
        label = "Fertilizer 1"
    elif max_mean == mean_fert2:
        label = "Fertiziler 2"
    else:
        label = "Fertilizer 3"
    
    return max_mean, label

max_mean, max_label = max_mean_label(mean_fert1, mean_fert2, mean_fert3)
print(f"The maximum mean value  of corn yielded for a fertiziler (in kg) is {max_mean} and it belongs to variable {max_label}.")
# Out:
# The Null Hypothesis states that there is no difference in average corn yield between Fertiziler 1, Fertilizer 2, and Fertilizer 3.
# The Alternative Hypothesis states that there is a difference in average corn yield between Fertiziler 1, Fertiziler 2, and Fertilizer 3
# ********************
# The f value of the anova test is 20.315789473684188
# The p value of the anova test is 0.00014047824793190475
# ********************
# Since the significance level is less than 5%, we reject the null hypothesis.
# ********************
# The maximum mean value  of corn yielded for a fertiziler (in kg) is 23.2 and it belongs to variable Fertilizer 3.
